# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
housing_data_master_load = "../Data/dataset.csv"
housing_data_master_df = pd.read_csv(housing_data_master_load)

# %%
housing_data_master_df.head()
# Out:
#           period    CS_Index  West North Central  New England  \
# 0   2000-January  100.589697              151.57       127.99
# 1  2000-February  101.692479              152.74       127.91
# 2     2000-March  102.783829              153.15       129.86
# 3     2000-April  103.996444              154.52       131.19
# 4       2000-May  105.252818              154.98       132.91
#
#    East North Central  Middle Atlantic  Mountain  Pacific  South Atlantic  \
# 0              150.48           118.85    165.07   122.51          133.79
# 1              149.71           118.42    165.48   121.47          134.19
# 2              151.06           119.62    166.34   123.09          134.77
# 3              151.77           120.61    166.87   123.86          135.89
# 4              152.17           121.02    167.46   125.02          136.52
#
#    West South Central     USA  Housing Affordability Index  \
# 0              139.65  137.42                        126.0
# 1              139.50  137.26                        126.6
# 2              140.74  138.32                        125.1
# 3              141.43  139.26                        124.1
# 4              141.90  139.89                        121.0
#
#    Market Absorption Rate (%)  Unemployment Rate  Financial obligations ratio  \
# 0                        67.0                4.0                    16.532775
# 1                        78.0                4.1                    16.574865
# 2                        88.0                4.0                    16.616956
# 3                        78.0                3.8                    16.659046
# 4                        77.0                4.0                    16.708283
#
#    Consumer debt service ratio  Debt service ratio  \
# 0                     5.937883           11.503203
# 1                     5.973133           11.555449
# 2                     6.008382           11.607695
# 3                     6.043632           11.659941
# 4                     6.088313           11.718836
#
#    Mortgage debt service ratio
# 0                     5.565320
# 1                     5.582317
# 2                     5.599313
# 3                     5.616310
# 4                     5.630523

# %%
housing_data_master_df.columns
# Out:
# Index(['period', 'CS_Index', 'West North Central', 'New England',
#        'East North Central', 'Middle Atlantic', 'Mountain', 'Pacific',
#        'South Atlantic', 'West South Central', 'USA',
#        'Housing Affordability Index', 'Market Absorption Rate (%)',
#        'Unemployment Rate', 'Financial obligations ratio',
#        'Consumer debt service ratio', 'Debt service ratio',
#        'Mortgage debt service ratio'],
#       dtype='object')

# %%
x_axis = housing_data_master_df["Housing Affordability Index"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["USA"]
trace0 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "USA", 
     c= "orange",edgecolor= "black" 
        
     )


data = [trace0]

x_axis = housing_data_master_df["Housing Affordability Index"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["Pacific"]
trace1 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "Pacific", 
     c= "yellow",edgecolor= "black"
        
     )


data = [trace1]

x_axis = housing_data_master_df["Housing Affordability Index"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["South Atlantic"]
trace2 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "South Atlantic", 
     c= "lightskyblue", edgecolor= "black"
    )
data = [trace2]
#py.iplot(data, filename='bubblechart-size')
plt.xlabel ("Housing Affordability")
plt.ylabel("Market Absorption")
plt.legend(title= "USA and Region")
plt.grid(True)
plt.title("Housing Affordability Impact on Housing Sales")
#plt.text(42,35,"Note: Circle size correlates with Region")
plt.show()

# %%
x_axis = housing_data_master_df["Debt service ratio"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["USA"]
trace0 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "USA", 
     c= "orange",edgecolor= "black" 
        
     )


data = [trace0]

x_axis = housing_data_master_df["Debt service ratio"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["Pacific"]
trace1 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "New England", 
     c= "yellow",edgecolor= "black"
        
     )


data = [trace1]

x_axis = housing_data_master_df["Debt service ratio"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["South Atlantic"]
trace2 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "East North Central", 
     c= "lightskyblue", edgecolor= "black"
    )
data = [trace2]
#py.iplot(data, filename='bubblechart-size')
plt.xlabel ("Debt service ratio")
plt.ylabel("Market Absorption")
plt.legend(title= "USA and Region")
plt.grid(True)
plt.title("Debt Impact on Housing Sales")
#plt.text(42,35,"Note: Circle size correlates with Region")
plt.show()

# %%
x_axis = housing_data_master_df["Consumer debt service ratio"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["USA"]
trace0 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "USA", 
     c= "orange",edgecolor= "black" 
        
     )


data = [trace0]

x_axis = housing_data_master_df["Consumer debt service ratio"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["Pacific"]
trace1 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "Pacific", 
     c= "yellow",edgecolor= "black"
        
     )


data = [trace1]

x_axis = housing_data_master_df["Consumer debt service ratio"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["South Atlantic"]
trace2 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "South Atlantic", 
     c= "lightskyblue", edgecolor= "black"
    )
data = [trace2]
#py.iplot(data, filename='bubblechart-size')
plt.xlabel ("Consumer debt service ratio")
plt.ylabel("Market Absorption")
plt.legend(title= "USA and Region")
plt.grid(True)
plt.title("Consumer Debt Impact on Housing Sales")
#plt.text(42,35,"Note: Circle size correlates with Region")
plt.show()

# %%
x_axis = housing_data_master_df["period"]
y_axis = housing_data_master_df["CS_Index"]
size_value = housing_data_master_df["CS_Index"]
trace0 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value,
     label= "CS_Index", 
     c= "orange",edgecolor= "black" 
        
     )


data = [trace0]

x_axis = housing_data_master_df["period"]
y_axis = housing_data_master_df["USA"]
size_value = housing_data_master_df["USA"]
trace1 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value,
     label= "USA", 
     c= "yellow",edgecolor= "black"
        
     )


#data = [trace1]

#x_axis = housing_data_master_df["Consumer debt service ratio"]
#y_axis = housing_data_master_df["Market Absorption Rate (%)"]
#size_value = housing_data_master_df["South Atlantic"]
#trace2 = plt.scatter(
#     x= x_axis,
#     y= y_axis,
#     marker= "o",
#     s= size_value/10,
#     label= "South Atlantic", 
#     c= "lightskyblue", edgecolor= "black"
#   )
#data = [trace2]
#py.iplot(data, filename='bubblechart-size')
#plt.xlabel ("Consumer debt service ratio")
#plt.ylabel("Market Absorption")
#plt.legend(title= "USA and Region")
#plt.grid(True)
#plt.title("Consumer Debt Impact on Housing Sales")
#plt.text(42,35,"Note: Circle size correlates with Region")
#plt.show()

# %%
# gca stands for 'get current axis'
ax = plt.gca()

housing_data_master_df.plot(kind='line',x='period',y='USA',ax=ax)
housing_data_master_df.plot(kind='line',x='period',y='CS_Index', color='red', ax=ax)
plt.title('USA vs CS Index by period')
plt.show()

# %%
# gca stands for 'get current axis'
ax = plt.gca()
plt.title('Housing Affordability Index vs CS Index by period')
housing_data_master_df.plot(kind='line',x='period',y='Housing Affordability Index',ax=ax)
housing_data_master_df.plot(kind='line',x='period',y='CS_Index', color='red', ax=ax)

plt.show()

# %%
# gca stands for 'get current axis'
ax = plt.gca()
plt.title('Financial Obligations Ratio vs CS Index by period')
housing_data_master_df.plot(kind='line',x='period',y='Financial obligations ratio', ax=ax)
housing_data_master_df.plot(kind='line',x='period',y='CS_Index', color='red', ax=ax)

plt.show()

# %%
# gca stands for 'get current axis'
ax = plt.gca()
plt.title('Unemployment Index vs CS Index by period')
housing_data_master_df.plot(kind='line',x='period',y='Unemployment Rate',ax=ax)
housing_data_master_df.plot(kind='line',x='period',y='CS_Index', color='red', ax=ax)

plt.show()
