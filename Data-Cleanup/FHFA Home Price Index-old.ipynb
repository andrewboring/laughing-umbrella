# %% [markdown]
# # FHFA Home Price Index

# %%
import pandas as pd

# %%
file = "../Data/FHFA/HPI_master.csv"
data = pd.read_csv(file)

# %%
data.head(12)
# Out:
#        hpi_type     hpi_flavor frequency                   level  \
# 0   traditional  purchase-only   monthly  USA or Census Division
# 1   traditional  purchase-only   monthly  USA or Census Division
# 2   traditional  purchase-only   monthly  USA or Census Division
# 3   traditional  purchase-only   monthly  USA or Census Division
# 4   traditional  purchase-only   monthly  USA or Census Division
# 5   traditional  purchase-only   monthly  USA or Census Division
# 6   traditional  purchase-only   monthly  USA or Census Division
# 7   traditional  purchase-only   monthly  USA or Census Division
# 8   traditional  purchase-only   monthly  USA or Census Division
# 9   traditional  purchase-only   monthly  USA or Census Division
# 10  traditional  purchase-only   monthly  USA or Census Division
# 11  traditional  purchase-only   monthly  USA or Census Division
#
#                      place_name place_id    yr  period  index_nsa  index_sa
# ...

# %%
data.rename(columns={'yr':'Year','period':'Month'}, inplace=True)

# %%
data.head()
# Out:
#       hpi_type     hpi_flavor frequency                   level  \
# 0  traditional  purchase-only   monthly  USA or Census Division
# 1  traditional  purchase-only   monthly  USA or Census Division
# 2  traditional  purchase-only   monthly  USA or Census Division
# 3  traditional  purchase-only   monthly  USA or Census Division
# 4  traditional  purchase-only   monthly  USA or Census Division
#
#                     place_name place_id  Year  Month  index_nsa  index_sa
# 0  East North Central Division   DV_ENC  1991      1     100.00    100.00
# 1  East North Central Division   DV_ENC  1991      2     100.99    101.07
# 2  East North Central Division   DV_ENC  1991      3     101.36    101.00
# 3  East North Central Division   DV_ENC  1991      4     101.74    101.04
# 4  East North Central Division   DV_ENC  1991      5     102.38    101.43

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107988 entries, 0 to 107987
# Data columns (total 10 columns):
# hpi_type      107988 non-null object
# hpi_flavor    107988 non-null object
# frequency     107988 non-null object
# level         107988 non-null object
# place_name    107988 non-null object
# place_id      107988 non-null object
# Year          107988 non-null int64
# Month         107988 non-null int64
# index_nsa     107986 non-null float64
# index_sa      35284 non-null float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 8.2+ MB

# %%
data['Month'] = data['Month'].apply(str)

# %%
data['Month'] = data['Month'].map({'1':'January', 
                                '2':'February',
                                '3':'March',
                                '4':'April',
                                '5':'May',
                                '6':'June',
                                '7':'July',
                                '8':'August',
                                '9':'September',
                                '10':'October',
                                '11':'November',
                                '12':'December',
                                })

# %%
data.hpi_type.unique()
# Out:
# array(['traditional', 'non-metro', 'distress-free', 'developmental'],
#       dtype=object)

# %%
data.hpi_flavor.unique()
# Out:
# array(['purchase-only', 'all-transactions', 'expanded-data'], dtype=object)

# %%
data.frequency.unique()
# Out:
# array(['monthly', 'quarterly'], dtype=object)

# %%
data.place_name.unique()
# Out:
# array(['East North Central Division', 'East South Central Division',
#        'Middle Atlantic Division', 'Mountain Division',
#        'New England Division', 'Pacific Division',
#        'South Atlantic Division', 'West North Central Division',
#        'West South Central Division', 'United States', 'Abilene, TX',
#        'Akron, OH', 'Albany, GA', 'Albany-Lebanon, OR',
#        'Albany-Schenectady-Troy, NY', 'Albuquerque, NM', 'Alexandria, LA',
#        'Allentown-Bethlehem-Easton, PA-NJ', 'Altoona, PA', 'Amarillo, TX',
#        'Ames, IA', 'Anaheim-Santa Ana-Irvine, CA (MSAD)', 'Anchorage, AK',
#        'Ann Arbor, MI', 'Anniston-Oxford, AL', 'Appleton, WI',
#        'Asheville, NC', 'Athens-Clarke County, GA',
#        'Atlanta-Sandy Springs-Alpharetta, GA',
#        'Atlantic City-Hammonton, NJ', 'Auburn-Opelika, AL',
#        'Augusta-Richmond County, GA-SC',
#        'Austin-Round Rock-Georgetown, TX', 'Bakersfield, CA',
# ...

# %%
data.level.unique()
# Out:
# array(['USA or Census Division', 'MSA', 'State', 'Puerto Rico'],
#       dtype=object)

# %% [markdown]
# # TBD
# Figure how whether to split or aggregate the dataframe above.
# Optional: Just get the Monthly purhcase-only index data to simplfy?
# https://www.fhfa.gov/DataTools/Downloads/Pages/House-Price-Index-Datasets.aspx#mpo

# %%
#what does quarterly data look like? how about "level"=State ?
data.loc[(data['frequency'] == 'quarterly') & (data['level'] == 'State')]
# Out:
#            hpi_type        hpi_flavor  frequency  level place_name place_id  \
# 60740   traditional  all-transactions  quarterly  State     Alaska       AK
# 60741   traditional  all-transactions  quarterly  State     Alaska       AK
# 60742   traditional  all-transactions  quarterly  State     Alaska       AK
# 60743   traditional  all-transactions  quarterly  State     Alaska       AK
# 60744   traditional  all-transactions  quarterly  State     Alaska       AK
# 60745   traditional  all-transactions  quarterly  State     Alaska       AK
# 60746   traditional  all-transactions  quarterly  State     Alaska       AK
# 60747   traditional  all-transactions  quarterly  State     Alaska       AK
# 60748   traditional  all-transactions  quarterly  State     Alaska       AK
# 60749   traditional  all-transactions  quarterly  State     Alaska       AK
# 60750   traditional  all-transactions  quarterly  State     Alaska       AK
# ...
