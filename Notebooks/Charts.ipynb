# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
housing_data_master_load = "Data/dataset.csv"
housing_data_master_df = pd.read_csv(housing_data_master_load)

# %%
housing_data_master_df.head()
# Out:
#      CS_Index         period  West North Central\n(SA)  New England\n\n(SA)  \
# 0  100.589697   2000-January                    151.57               127.99
# 1  101.692479  2000-February                    152.74               127.91
# 2  102.783829     2000-March                    153.15               129.86
# 3  103.996444     2000-April                    154.52               131.19
# 4  105.252818       2000-May                    154.98               132.91
#
#    East North Central\n(SA)  Middle Atlantic\n(SA)  Mountain\n\n(SA)  \
# 0                    150.48                 118.85            165.07
# 1                    149.71                 118.42            165.48
# 2                    151.06                 119.62            166.34
# 3                    151.77                 120.61            166.87
# 4                    152.17                 121.02            167.46
#
#    New England\n\n(SA).1  Pacific\n\n(SA)  South Atlantic\n(SA)  \
# ...

# %%
housing_data_master_df.columns
# Out:
# Index(['CS_Index', 'period', 'West North Central\n(SA)', 'New England\n\n(SA)',
#        'East North Central\n(SA)', 'Middle Atlantic\n(SA)', 'Mountain\n\n(SA)',
#        'New England\n\n(SA).1', 'Pacific\n\n(SA)', 'South Atlantic\n(SA)',
#        'West North Central\n(SA).1', 'West South Central\n(SA)', 'USA\n\n(SA)',
#        'Housing_Affordability_Index', 'Market Absorption Rate (%)', 'Value',
#        'Financial obligations ratio, seasonally adjusted',
#        'Consumer debt service ratio, seasonally adjusted',
#        'Debt service ratio, seasonally adjusted',
#        'Mortgage debt service ratio, seasonally adjusted'],
#       dtype='object')

# %%
x_axis = housing_data_master_df["Housing_Affordability_Index"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["USA\n\n(SA)"]
trace0 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value*10,
     label= "USA", 
     c= "orange",edgecolor= "black" 
        
     )


data = [trace0]

x_axis = housing_data_master_df["Housing_Affordability_Index"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["Pacific\n\n(SA)"]
trace1 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value*10,
     label= "Pacific", 
     c= "yellow",edgecolor= "black"
        
     )


data = [trace1]

x_axis = housing_data_master_df["Housing_Affordability_Index"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["South Atlantic\n(SA)"]
trace2 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value*10,
     label= "South Atlantic", 
     c= "lightskyblue", edgecolor= "black"
    )
data = [trace2]
#py.iplot(data, filename='bubblechart-size')
plt.xlabel ("Housing Affordability")
plt.ylabel("Market Absorption")
plt.legend(title= "USA and Region")
plt.grid(True)
plt.title("Housing Affordability Impact on Housing Sales")
#plt.text(42,35,"Note: Circle size correlates with Region")
plt.show()
