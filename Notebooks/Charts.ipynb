# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
housing_data_master_load = "../Data/dataset.csv"
housing_data_master_df = pd.read_csv(housing_data_master_load)

# %%
housing_data_master_df.head()
# Out:
#           period    CS_Index  West North Central  New England  \
# 0   2000-January  100.589697              151.57       127.99
# 1  2000-February  101.692479              152.74       127.91
# 2     2000-March  102.783829              153.15       129.86
# 3     2000-April  103.996444              154.52       131.19
# 4       2000-May  105.252818              154.98       132.91
#
#    East North Central  Middle Atlantic  Mountain  New England.1  Pacific  \
# 0              150.48           118.85    165.07         127.99   122.51
# 1              149.71           118.42    165.48         127.91   121.47
# 2              151.06           119.62    166.34         129.86   123.09
# 3              151.77           120.61    166.87         131.19   123.86
# 4              152.17           121.02    167.46         132.91   125.02
#
#    South Atlantic  West North Central.1  West South Central     USA  \
# 0          133.79                151.57              139.65  137.42
# 1          134.19                152.74              139.50  137.26
# 2          134.77                153.15              140.74  138.32
# 3          135.89                154.52              141.43  139.26
# 4          136.52                154.98              141.90  139.89
#
#    Housing Affordability Index  Market Absorption Rate (%)  Unemployment Rate  \
# 0                        126.0                        67.0                4.0
# 1                        126.6                        78.0                4.1
# 2                        125.1                        88.0                4.0
# 3                        124.1                        78.0                3.8
# 4                        121.0                        77.0                4.0
#
#    Financial obligations ratio, seasonally adjusted  \
# 0                                         16.532775
# 1                                         16.574865
# 2                                         16.616956
# 3                                         16.659046
# 4                                         16.708283
#
#    Consumer debt service ratio, seasonally adjusted  \
# 0                                          5.937883
# 1                                          5.973133
# 2                                          6.008382
# 3                                          6.043632
# 4                                          6.088313
#
#    Debt service ratio, seasonally adjusted  \
# 0                                11.503203
# 1                                11.555449
# 2                                11.607695
# 3                                11.659941
# 4                                11.718836
#
#    Mortgage debt service ratio, seasonally adjusted
# 0                                          5.565320
# 1                                          5.582317
# 2                                          5.599313
# 3                                          5.616310
# 4                                          5.630523

# %%
housing_data_master_df.columns
# Out:
# Index(['period', 'CS_Index', 'West North Central', 'New England',
#        'East North Central', 'Middle Atlantic', 'Mountain', 'New England.1',
#        'Pacific', 'South Atlantic', 'West North Central.1',
#        'West South Central', 'USA', 'Housing Affordability Index',
#        'Market Absorption Rate (%)', 'Unemployment Rate',
#        'Financial obligations ratio, seasonally adjusted',
#        'Consumer debt service ratio, seasonally adjusted',
#        'Debt service ratio, seasonally adjusted',
#        'Mortgage debt service ratio, seasonally adjusted'],
#       dtype='object')

# %%
x_axis = housing_data_master_df["Housing Affordability Index"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["USA"]
trace0 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "USA", 
     c= "orange",edgecolor= "black" 
        
     )


data = [trace0]

x_axis = housing_data_master_df["Housing Affordability Index"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["Pacific"]
trace1 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "Pacific", 
     c= "yellow",edgecolor= "black"
        
     )


data = [trace1]

x_axis = housing_data_master_df["Housing Affordability Index"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["South Atlantic"]
trace2 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "South Atlantic", 
     c= "lightskyblue", edgecolor= "black"
    )
data = [trace2]
#py.iplot(data, filename='bubblechart-size')
plt.xlabel ("Housing Affordability")
plt.ylabel("Market Absorption")
plt.legend(title= "USA and Region")
plt.grid(True)
plt.title("Housing Affordability Impact on Housing Sales")
#plt.text(42,35,"Note: Circle size correlates with Region")
plt.show()

# %%
x_axis = housing_data_master_df["Debt service ratio, seasonally adjusted"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["USA"]
trace0 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "USA", 
     c= "orange",edgecolor= "black" 
        
     )


data = [trace0]

x_axis = housing_data_master_df["Debt service ratio, seasonally adjusted"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["Pacific"]
trace1 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "New England", 
     c= "yellow",edgecolor= "black"
        
     )


data = [trace1]

x_axis = housing_data_master_df["Debt service ratio, seasonally adjusted"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["South Atlantic"]
trace2 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "East North Central", 
     c= "lightskyblue", edgecolor= "black"
    )
data = [trace2]
#py.iplot(data, filename='bubblechart-size')
plt.xlabel ("Debt service ratio, seasonally adjusted")
plt.ylabel("Market Absorption")
plt.legend(title= "USA and Region")
plt.grid(True)
plt.title("Debt Impact on Housing Sales")
#plt.text(42,35,"Note: Circle size correlates with Region")
plt.show()

# %%
x_axis = housing_data_master_df["Consumer debt service ratio, seasonally adjusted"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["USA"]
trace0 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "USA", 
     c= "orange",edgecolor= "black" 
        
     )


data = [trace0]

x_axis = housing_data_master_df["Consumer debt service ratio, seasonally adjusted"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["Pacific"]
trace1 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "Pacific", 
     c= "yellow",edgecolor= "black"
        
     )


data = [trace1]

x_axis = housing_data_master_df["Consumer debt service ratio, seasonally adjusted"]
y_axis = housing_data_master_df["Market Absorption Rate (%)"]
size_value = housing_data_master_df["South Atlantic"]
trace2 = plt.scatter(
     x= x_axis,
     y= y_axis,
     marker= "o",
     s= size_value/10,
     label= "South Atlantic", 
     c= "lightskyblue", edgecolor= "black"
    )
data = [trace2]
#py.iplot(data, filename='bubblechart-size')
plt.xlabel ("Consumer debt service ratio, seasonally adjusted")
plt.ylabel("Market Absorption")
plt.legend(title= "USA and Region")
plt.grid(True)
plt.title("Consumer Debt Impact on Housing Sales")
#plt.text(42,35,"Note: Circle size correlates with Region")
plt.show()
